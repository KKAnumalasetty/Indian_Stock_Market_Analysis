# %% [markdown]
# # NSE blocks selenium using bot detection and doesn't return any data
#
# ## No solution found to bypass these selenium detetion bots
#
# https://stackoverflow.com/questions/59872920/clicking-on-get-data-button-for-monthly-settlement-statistics-on-nseindia-com-do

# %%
# !pip install selenium

# %%
from selenium import webdriver
from datetime import datetime

# %%
# chrome_driver = webdriver.Chrome("C:\\softwares\\Data Science Tools\\selenium_chromedriver_win32\\chromedriver.exe")
# chrome_driver.get('https://www1.nseindia.com/products/content/equities/indices/historical_pepb.htm')


firefox_driver = webdriver.Firefox(executable_path="C:/softwares/Data Science Tools/firefoxt_selenium_webdriver/geckodriver.exe")
firefox_driver.get('https://www1.nseindia.com/products/content/equities/indices/historical_pepb.htm')

from_date_input = firefox_driver.find_element_by_xpath('//*[@id="fromDate"]')
from_date_input.send_keys("01-06-2020")
print('From date set: ',datetime.now())


to_date_input = firefox_driver.find_element_by_xpath('//*[@id="toDate"]')
to_date_input.send_keys("10-06-2020")
print('To date set: ',datetime.now())


pe_checkbox = firefox_driver.find_element_by_xpath('//*[@id="yield1"]').click()
print('checkbox clicked : ',datetime.now())


get_data_button = firefox_driver.find_element_by_xpath('//*[@id="get"]').click()
print('Get data button clicked : ',datetime.now())


# resources_link.click()
# Out:
# From date set:  2020-06-10 21:50:13.426974
# To date set:  2020-06-10 21:50:13.868790
# checkbox clicked :  2020-06-10 21:50:14.108152
# Get data button clicked :  2020-06-10 21:50:14.343523

# %% [markdown]
# # Leveraging Manually downloaded data

# %%
import plotly.graph_objects as go

x=['Winter', 'Spring', 'Summer', 'Fall']

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x, y=[10, 10, 10, 10],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='green'),
    fill = 'tonexty',
    text="-2 Std. Dev",
))
fig.add_trace(go.Scatter(
    x=x, y=[10, 10, 10, 10],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='grey'),
))

fig.add_trace(go.Scatter(
    x=x, y=[25, 25, 25, 25],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='lightgreen'),
    fill = 'tonexty'
))
fig.add_trace(go.Scatter(
    x=x, y=[25, 25, 25, 25],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='grey'),
))

fig.add_trace(go.Scatter(
    x=x, y=[50, 50, 50, 50],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='yellow'),
    fill = 'tonexty'
))
fig.add_trace(go.Scatter(
    x=x, y=[50, 50, 50, 50],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='grey'),
))


fig.add_trace(go.Scatter(
    x=x, y=[40, 30, 50, 30],
    hoverinfo='x+y',
    mode='lines+markers',
    line=dict(width=5, color='black'),
#     fill='tonexty'
))
fig.add_trace(go.Scatter(
    x=x, y=[60, 60, 60, 60],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='magenta'),
    fill = 'tonexty'
))
fig.add_trace(go.Scatter(
    x=x, y=[60, 60, 60, 60],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='grey'),
))

fig.add_trace(go.Scatter(
    x=x, y=[100, 100, 100, 100],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='red'),
    fill = 'tonexty'
))
fig.add_trace(go.Scatter(
    x=x, y=[100, 100, 100, 100],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='grey'),
))


fig.update_layout(yaxis_range=(0, 110),
                     annotations=[
                        dict(x=1,y=10,xref="x",yref="y",text="-2 Std. Dev",showarrow=False,arrowhead=1,ax=10,ay=-40),
                        dict(x=1,y=25,xref="x",yref="y",text="-1 Std. Dev",showarrow=False,arrowhead=1,ax=10,ay=-40),
                        dict(x=1,y=50,xref="x",yref="y",text="Mean",showarrow=False,arrowhead=1,ax=10,ay=-40),
                        dict(x=1,y=60,xref="x",yref="y",text="1 Std. Dev",showarrow=False,arrowhead=1,ax=10,ay=-40),
                        dict(x=1,y=80,xref="x",yref="y",text="2 Std. Dev",showarrow=False,arrowhead=1,ax=10,ay=-40),
    ],
                  showlegend=False,
)
fig.show()
# Out:
# <div>
#
#
#             <div id="e3cb76e8-59a5-4924-827b-194975763732" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3cb76e8-59a5-4924-827b-194975763732")) {
#                     Plotly.newPlot(
#                         'e3cb76e8-59a5-4924-827b-194975763732',
#                         [{"fill": "tonexty", "hoverinfo": "x+y", "line": {"color": "green", "width": 0.5}, "mode": "lines", "text": "-2 Std. Dev", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [10, 10, 10, 10]}, {"hoverinfo": "x+y", "line": {"color": "grey", "width": 2}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [10, 10, 10, 10]}, {"fill": "tonexty", "hoverinfo": "x+y", "line": {"color": "lightgreen", "width": 0.5}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [25, 25, 25, 25]}, {"hoverinfo": "x+y", "line": {"color": "grey", "width": 2}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [25, 25, 25, 25]}, {"fill": "tonexty", "hoverinfo": "x+y", "line": {"color": "yellow", "width": 0.5}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [50, 50, 50, 50]}, {"hoverinfo": "x+y", "line": {"color": "grey", "width": 2}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [50, 50, 50, 50]}, {"hoverinfo": "x+y", "line": {"color": "black", "width": 5}, "mode": "lines+markers", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [40, 30, 50, 30]}, {"fill": "tonexty", "hoverinfo": "x+y", "line": {"color": "magenta", "width": 0.5}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [60, 60, 60, 60]}, {"hoverinfo": "x+y", "line": {"color": "grey", "width": 2}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [60, 60, 60, 60]}, {"fill": "tonexty", "hoverinfo": "x+y", "line": {"color": "red", "width": 0.5}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [100, 100, 100, 100]}, {"hoverinfo": "x+y", "line": {"color": "grey", "width": 2}, "mode": "lines", "type": "scatter", "x": ["Winter", "Spring", "Summer", "Fall"], "y": [100, 100, 100, 100]}],
#                         {"annotations": [{"arrowhead": 1, "ax": 10, "ay": -40, "showarrow": false, "text": "-2 Std. Dev", "x": 1, "xref": "x", "y": 10, "yref": "y"}, {"arrowhead": 1, "ax": 10, "ay": -40, "showarrow": false, "text": "-1 Std. Dev", "x": 1, "xref": "x", "y": 25, "yref": "y"}, {"arrowhead": 1, "ax": 10, "ay": -40, "showarrow": false, "text": "Mean", "x": 1, "xref": "x", "y": 50, "yref": "y"}, {"arrowhead": 1, "ax": 10, "ay": -40, "showarrow": false, "text": "1 Std. Dev", "x": 1, "xref": "x", "y": 60, "yref": "y"}, {"arrowhead": 1, "ax": 10, "ay": -40, "showarrow": false, "text": "2 Std. Dev", "x": 1, "xref": "x", "y": 80, "yref": "y"}], "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], " ...

# %%
import glob
import pandas as pd

glued_data = pd.DataFrame()
for file_name in glob.glob('*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)
glued_data
# Out:
#             Date    P/E
# 0    01-Jan-2008  27.64
# 1    02-Jan-2008  27.80
# 2    03-Jan-2008  27.80
# 3    04-Jan-2008  28.23
# 4    07-Jan-2008  28.25
# ..           ...    ...
# 104  04-Jun-2020  23.42
# 105  05-Jun-2020  23.91
# 106  08-Jun-2020  23.97
# 107  09-Jun-2020  24.25
# 108  10-Jun-2020  24.41
#
# [3067 rows x 2 columns]

# %%
glued_data['Mean_PE'] = glued_data['P/E'].mean()

glued_data['1std_dev_PE'] = glued_data['Mean_PE']+glued_data['P/E'].std()
glued_data['Neg_1std_dev_PE'] = glued_data['Mean_PE']-glued_data['P/E'].std()

glued_data['1_5_std_dev_PE'] = glued_data['Mean_PE']+(1.5*glued_data['P/E'].std())



glued_data['2std_dev_PE'] = glued_data['Mean_PE']+(2*glued_data['P/E'].std())
glued_data['Neg_2std_dev_PE'] = glued_data['Mean_PE']-(2*glued_data['P/E'].std())


# glued_data['Mean_PE'] = glued_data['P/E'].mean()
# glued_data['Mean_PE'] = glued_data['P/E'].mean()
# glued_data['Mean_PE'] = glued_data['P/E'].mean()

glued_data
# Out:
#             Date    P/E    Mean_PE  1std_dev_PE  Neg_1std_dev_PE  2std_dev_PE  \
# 0    01-Jan-2008  27.64  21.656779    25.397004        17.916553    29.137229
# 1    02-Jan-2008  27.80  21.656779    25.397004        17.916553    29.137229
# 2    03-Jan-2008  27.80  21.656779    25.397004        17.916553    29.137229
# 3    04-Jan-2008  28.23  21.656779    25.397004        17.916553    29.137229
# 4    07-Jan-2008  28.25  21.656779    25.397004        17.916553    29.137229
# ..           ...    ...        ...          ...              ...          ...
# 104  04-Jun-2020  23.42  21.656779    25.397004        17.916553    29.137229
# 105  05-Jun-2020  23.91  21.656779    25.397004        17.916553    29.137229
# 106  08-Jun-2020  23.97  21.656779    25.397004        17.916553    29.137229
# 107  09-Jun-2020  24.25  21.656779    25.397004        17.916553    29.137229
# 108  10-Jun-2020  24.41  21.656779    25.397004        17.916553    29.137229
#
#      Neg_2std_dev_PE  1_5_std_dev_PE
# 0          14.176328       27.267117
# 1          14.176328       27.267117
# 2          14.176328       27.267117
# 3          14.176328       27.267117
# 4          14.176328       27.267117
# ..               ...             ...
# 104        14.176328       27.267117
# 105        14.176328       27.267117
# 106        14.176328       27.267117
# 107        14.176328       27.267117
# 108        14.176328       27.267117
#
# [3067 rows x 8 columns]

# %%
import plotly.express as px

x = glued_data['Date']
fig = px.line(glued_data, x='Date', y='P/E')

fig.add_trace(go.Scatter(
    x=x, y=glued_data['Mean_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=2, color='black'),
))

fig.add_trace(go.Scatter(
    x=x, y=glued_data['1_5_std_dev_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=4, color='yellow'),
))


fig.add_trace(go.Scatter(
    x=x, y=glued_data['1std_dev_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=4, color='red'),
))

fig.add_trace(go.Scatter(
    x=x, y=glued_data['Neg_1std_dev_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=4, color='green'),
))


fig.add_trace(go.Scatter(
    x=x, y=glued_data['2std_dev_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=4, color='red'),
))

fig.add_trace(go.Scatter(
    x=x, y=glued_data['Neg_2std_dev_PE'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=4, color='green'),
))



fig.update_xaxes(rangeslider_visible=True,
                    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
                    )
)
fig.show()
# Out:
# <div>
#
#
#             <div id="71b3d276-99fc-448e-9f42-a052adde9cbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71b3d276-99fc-448e-9f42-a052adde9cbe")) {
#                     Plotly.newPlot(
#                         '71b3d276-99fc-448e-9f42-a052adde9cbe',
#                         [{"hovertemplate": "Date=%{x}<br>P/E=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["01-Jan-2008", "02-Jan-2008", "03-Jan-2008", "04-Jan-2008", "07-Jan-2008", "08-Jan-2008", "09-Jan-2008", "10-Jan-2008", "11-Jan-2008", "14-Jan-2008", "15-Jan-2008", "16-Jan-2008", "17-Jan-2008", "18-Jan-2008", "21-Jan-2008", "22-Jan-2008", "23-Jan-2008", "24-Jan-2008", "25-Jan-2008", "28-Jan-2008", "29-Jan-2008", "30-Jan-2008", "31-Jan-2008", "01-Feb-2008", "04-Feb-2008", "05-Feb-2008", "06-Feb-2008", "07-Feb-2008", "08-Feb-2008", "11-Feb-2008", "12-Feb-2008", "13-Feb-2008", "14-Feb-2008", "15-Feb-2008", "18-Feb-2008", "19-Feb-2008", "20-Feb-2008", "21-Feb-2008", "22-Feb-2008", "25-Feb-2008", "26-Feb-2008", "27-Feb-2008", "28-Feb-2008", "29-Feb-2008", "03-Mar-2008", "04-Mar-2008", "05-Mar-2008", "07-Mar-2008", "10-Mar-2008", "11-Mar-2008", "12-Mar-2008", "13-Mar-2008", "14-Mar-2008", "17-Mar-2008", "18-Mar-2008", "19-Mar-2008", "24-Mar-2008", "25-Mar-2008", "26-Mar-2008", "27-Mar-2008", "28-Mar-2008", "31-Mar-2008", "01-Apr-2008", "02-Apr-2008", "03-Apr-2008", "04-Apr-2008", "07-Apr-2008", "08-Apr-2008", "09-Apr-2008", "10-Apr-2008", "11-Apr-2008", "15-Apr-2008", "16-Apr-2008", "17-Apr-2008", "21-Apr-2008", "22-Apr-2008", "23-Apr-2008", "24-Apr-2008", "25-Apr-2008", "28-Apr-2008", "29-Apr-2008", "30-Apr-2008", "02-May-2008", "05-May-2008", "06-May-2008", "07-May-2008", "08-May-2008", "09-May-2008", "12-May-2008", "13-May-2008", "14-May-2008", "15-May-2008", "16-May-2008", "20-May-2008", "21-May-2008", "22-May-2008